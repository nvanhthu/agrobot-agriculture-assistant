# %%
import pdfplumber
import os

# PDF extraction function
def extract_text_from_pdf(pdf_path):
    text = ''
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text + '\n'
    return text

# Input folder where PDFs are stored
data_folder = "Data"

# Output folder to save processed text files
output_folder = "Processed_Data"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# List of PDF files
pdf_files = [
    "Charts_Veg_BC.pdf",
    "577300-0_irrigmgmtguide_chapter_05_with_titlepage.pdf",
    "FV04-Fraser-Valley-Pest-Assessment-Inventory2016.pdf",
    "aa_booklet_cover_crops_bc.pdf",
    "resolving_farm_concerns_and_complaints.pdf",
    "farm_practices_in_bc_reference_guide.pdf"
]

for pdf_file in pdf_files:
    pdf_path = os.path.join(data_folder, pdf_file)
    print(f"Extracting from {pdf_path} ...")
    text = extract_text_from_pdf(pdf_path)
    print(f" - Extracted {len(text)} characters")
    txt_path = os.path.join(output_folder, pdf_file.replace(".pdf", ".txt"))
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write(text)
    print(f" - Saved to {txt_path}\n")

print("✅ All PDFs processed and saved in 'Processed_Data' folder.")
# Out:
# Extracting from Data\Charts_Veg_BC.pdf ...
# CropBox missing from /Page, defaulting to MediaBox
#  - Extracted 930 characters
#  - Saved to Processed_Data\Charts_Veg_BC.txt
#
# Extracting from Data\577300-0_irrigmgmtguide_chapter_05_with_titlepage.pdf ...
# CropBox missing from /Page, defaulting to MediaBox
#  - Extracted 31823 characters
#  - Saved to Processed_Data\577300-0_irrigmgmtguide_chapter_05_with_titlepage.txt
#
# Extracting from Data\FV04-Fraser-Valley-Pest-Assessment-Inventory2016.pdf ...
#  - Extracted 341395 characters
#  - Saved to Processed_Data\FV04-Fraser-Valley-Pest-Assessment-Inventory2016.txt
#
# Extracting from Data\aa_booklet_cover_crops_bc.pdf ...
#  - Extracted 111696 characters
#  - Saved to Processed_Data\aa_booklet_cover_crops_bc.txt
#
# Extracting from Data\resolving_farm_concerns_and_complaints.pdf ...
#  - Extracted 0 characters
#  - Saved to Processed_Data\resolving_farm_concerns_and_complaints.txt
#
# ...
